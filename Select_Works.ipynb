# %%
import csv
import csv
import os
import re
import utils
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/media/daniel/HDD1/AI574/Project/utils.py'>

# %%
relative_file_path = "metadata.csv"
file_path = os.path.abspath(relative_file_path)
print(file_path)
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
else:
    print(f"File not found: {file_path}")
# Out:
# /media/daniel/HDD1/AI574/Project/metadata.csv

# %%
df['subjects'] = df['subjects'].str.replace(r'[^\w\s]', '', regex=True)

# %%
# filtered_df = df[df['id']=='PG10038']

# %%
filtered_df = df[df['subjects'].str.contains("fiction", case=False, na=False)]

# %%
selected_works = filtered_df['id']

# %%
# selected_works = selected_works[:1]
selected_works
# Out:
# 2        PG10002
# 5        PG10005
# 6        PG10006
# 7        PG10007
# 8        PG10008
#           ...
# 71592     PG9983
# 71595     PG9986
# 71597     PG9988
# 71600     PG9990
# 71603     PG9993
# Name: id, Length: 27322, dtype: object

# %%
data_dir = '/media/daniel/HDD1/AI574/gutenberg/data/raw'

# %%
# cur_txt = ''
# with open(file_path, mode='r', newline='') as file:
#     csv_reader = csv.reader(file)
#     for row in csv_reader:
#         cur_txt += ' '.join(row) + ' '
# cur_txt = utils.remove_special_characters(cur_txt, remove_digits=True).lower()
# named_person_count = utils.count_named_persons_w_spacy(cur_txt)

# %%
# named_person_count
# Out:
# 55

# %%
named_persons = []
i=0
for fname in selected_works:
    i += 1
    fname = fname + "_raw.txt"
    file_path = os.path.join(data_dir,fname)
    cur_txt = ''
    with open(file_path, mode='r', newline='') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            cur_txt += ' '.join(row) + ' '
    cur_txt = utils.remove_special_characters(cur_txt, remove_digits=True).lower()
    named_person_count = (utils.count_named_persons_w_spacy(cur_txt))
    print(i, fname, named_person_count)
    named_persons.append(named_person_count)
# Out:
# 1 PG10002_raw.txt 14
# 2 PG10005_raw.txt 51
# 3 PG10006_raw.txt 17
# 4 PG10007_raw.txt 17
# 5 PG10008_raw.txt 53
# 6 PG10021_raw.txt 75
# 7 PG10025_raw.txt 213
# 8 PG10027_raw.txt 87
# 9 PG10037_raw.txt 200
# 10 PG10038_raw.txt 338
# 11 PG10041_raw.txt 177
# 12 PG10045_raw.txt 143
# 13 PG10046_raw.txt 122
# 14 PG10048_raw.txt 57
# 15 PG10049_raw.txt 37
# 16 PG10050_raw.txt 7
# 17 PG10051_raw.txt 8
# 18 PG10052_raw.txt 36
# 19 PG10053_raw.txt 2814
# 20 PG10057_raw.txt 83
# 21 PG10059_raw.txt 147
# 22 PG10062_raw.txt 397
# 23 PG10064_raw.txt 434
# 24 PG10066_raw.txt 109
# 25 PG10067_raw.txt 30
# 26 PG10068_raw.txt 184
# 27 PG10076_raw.txt 124
# 28 PG10081_raw.txt 115
# 29 PG10082_raw.txt 109
# 30 PG10084_raw.txt 80
# 31 PG10086_raw.txt 91
# 32 PG10087_raw.txt 125
# 33 PG10093_raw.txt 62
# 34 PG10094_raw.txt 144
# 35 PG10095_raw.txt 122
# 36 PG10101_raw.txt 49
# 37 PG10109_raw.txt 43
# 38 PG10110_raw.txt 120
# 39 PG10117_raw.txt 6932
# 40 PG10123_raw.txt 198
# 41 PG10124_raw.txt 122
# ...

# %%
cur_txt
# Out:
# ' the project gutenberg ebook of the magnetic north this ebook is for the use of anyone anywhere in the united states and most other parts of the world at no cost and with almost no restrictions whatsoever you may copy it give it away or re use it under the terms of the project gutenberg license included with this ebook or online at www gutenberg org if you are not located in the united states you will have to check the laws of the country where you are located before using this ebook title the magnetic north author elizabeth robins release date november ebook most recently updated december language english start of the project gutenberg ebook the magnetic north produced by suzanne shell anita paque shawn wheeler david schaal anuradha valsa raj and pg distributed proofreaders the magnetic north by elizabeth robins c e raimond author of "the open question below the salt etc with a map contents chapter i winter camp in the yukon ii house warming iii two new spissimens iv the blow out v
# ...
